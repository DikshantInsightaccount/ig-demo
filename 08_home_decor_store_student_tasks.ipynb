# %% [markdown]
# # Home Decor Store - Student Practice Notebook
#
# Dataset file: `08_home_decor_store.csv`
#
# Solve each task in the empty code cell below it.

# %% [markdown]
# ## Task 1
#
# Load the dataset into a pandas DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("08_home_decor_store.csv")

# %% [markdown]
# ## Task 2
#
# Display the first 10 rows of the DataFrame.

# %%
df.head(10)
# Out:
#       Order_ID  Order_Date   Customer_Segment   Region Product_Category  \
# 0  08ORD100522  2025-06-02  Interior Designer     West     Decor Pieces
# 1  08ORD100738  2025-01-08  Interior Designer     West         Wall Art
# 2  08ORD100741  2025-09-24        Residential     West         Wall Art
# 3  08ORD100661  2024-09-06        Residential    South             Rugs
# 4  08ORD100412  2024-03-25          Corporate     West         Wall Art
# 5  08ORD100679  2024-11-19        Residential  Central         Curtains
# 6  08ORD100627  2025-10-08        Residential  Central     Decor Pieces
# 7  08ORD100514  2025-03-09         Gift Buyer  Central         Curtains
# 8  08ORD100860  2024-12-01         Gift Buyer     East         Wall Art
# 9  08ORD100137  2025-03-06          Corporate     East             Rugs
#
#      Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 0  Cash on Delivery         3     2003.04                24      4566.93
# ...

# %% [markdown]
# ## Task 3
#
# Display the last 7 rows of the DataFrame.

# %%
df.tail(7)
# Out:
#         Order_ID  Order_Date   Customer_Segment   Region Product_Category  \
# 993  08ORD100701  2024-03-20          Corporate    North             Rugs
# 994  08ORD100072  2024-06-02        Residential     West         Lighting
# 995  08ORD100107  2025-08-18  Interior Designer     West     Decor Pieces
# 996  08ORD100271  2025-05-15          Corporate  Central             Rugs
# 997  08ORD100861  2024-09-12  Interior Designer    North         Wall Art
# 998  08ORD100436  2024-05-15          Corporate     West         Curtains
# 999  08ORD100103  2025-05-03  Interior Designer     East             Rugs
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 993       Credit Card         3     5703.40                15     14543.67
# 994  Cash on Delivery         1    12167.00                 6     11436.98
# 995        Debit Card         2     3384.99                 8      6228.38
# 996               UPI         1     2269.52                10      2042.57
# ...

# %% [markdown]
# ## Task 4
#
# Check the shape of the DataFrame.

# %%
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# ## Task 5
#
# List all column names.

# %%
columns = df.columns.tolist()
print(columns)
# Out:
# ['Order_ID', 'Order_Date', 'Customer_Segment', 'Region', 'Product_Category', 'Payment_Method', 'Quantity', 'Unit_Price', 'Discount_Percent', 'Order_Value']

# %% [markdown]
# ## Task 6
#
# Check the data types of all columns.

# %%
df.dtypes
# Out:
# Order_ID                str
# Order_Date              str
# Customer_Segment        str
# Region                  str
# Product_Category        str
# Payment_Method          str
# Quantity              int64
# Unit_Price          float64
# Discount_Percent      int64
# Order_Value         float64
# dtype: object

# %% [markdown]
# ## Task 7
#
# Display basic information using info().

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   str
#  1   Order_Date        1000 non-null   str
#  2   Customer_Segment  1000 non-null   str
#  3   Region            1000 non-null   str
#  4   Product_Category  1000 non-null   str
#  5   Payment_Method    1000 non-null   str
#  6   Quantity          1000 non-null   int64
#  7   Unit_Price        1000 non-null   float64
#  8   Discount_Percent  1000 non-null   int64
#  9   Order_Value       1000 non-null   float64
# dtypes: float64(2), int64(2), str(6)
# memory usage: 78.3 KB

# %% [markdown]
# ## Task 8
#
# Generate summary statistics for numerical columns.

# %%
df.describe()
# Out:
#           Quantity    Unit_Price  Discount_Percent   Order_Value
# count  1000.000000   1000.000000       1000.000000   1000.000000
# mean      2.001000  12278.096220         22.334000  18932.113760
# std       1.088202   7232.054923         13.286722  16427.712464
# min       1.000000    151.330000          0.000000    119.890000
# 25%       1.000000   6196.745000         10.750000   7015.832500
# 50%       2.000000  11903.120000         22.000000  13845.610000
# 75%       3.000000  18660.295000         34.000000  26476.410000
# max       4.000000  24998.310000         45.000000  97690.510000

# %% [markdown]
# ## Task 9
#
# Generate summary statistics for categorical columns.

# %%
df.describe(include='str')
# Out:
#            Order_ID  Order_Date Customer_Segment   Region Product_Category  \
# count          1000        1000             1000     1000             1000
# unique         1000         558                4        5                5
# top     08ORD100522  2024-12-30      Residential  Central             Rugs
# freq              1           6              264      224              219
#
#        Payment_Method
# count            1000
# unique              5
# top               UPI
# freq              221

# %% [markdown]
# ## Task 10
#
# Check whether the DataFrame contains any missing values.

# %%
df.isna()
# Out:
#      Order_ID  Order_Date  Customer_Segment  Region  Product_Category  \
# 0       False       False             False   False             False
# 1       False       False             False   False             False
# 2       False       False             False   False             False
# 3       False       False             False   False             False
# 4       False       False             False   False             False
# ..        ...         ...               ...     ...               ...
# 995     False       False             False   False             False
# 996     False       False             False   False             False
# 997     False       False             False   False             False
# 998     False       False             False   False             False
# 999     False       False             False   False             False
#
#      Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# ...

# %% [markdown]
# ## Task 11
#
# Count the missing values in each column.

# %%
df.isna().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_Segment    0
# Region              0
# Product_Category    0
# Payment_Method      0
# Quantity            0
# Unit_Price          0
# Discount_Percent    0
# Order_Value         0
# dtype: int64

# %% [markdown]
# ## Task 12
#
# Check whether there are any duplicate rows.

# %%
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# ## Task 13
#
# Count the duplicate rows in the DataFrame.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Task 14
#
# Drop duplicate rows if any exist.

# %%
newDf = df.drop_duplicates()
print(newDf)
# Out:
#         Order_ID  Order_Date   Customer_Segment   Region Product_Category  \
# 0    08ORD100522  2025-06-02  Interior Designer     West     Decor Pieces
# 1    08ORD100738  2025-01-08  Interior Designer     West         Wall Art
# 2    08ORD100741  2025-09-24        Residential     West         Wall Art
# 3    08ORD100661  2024-09-06        Residential    South             Rugs
# 4    08ORD100412  2024-03-25          Corporate     West         Wall Art
# ..           ...         ...                ...      ...              ...
# 995  08ORD100107  2025-08-18  Interior Designer     West     Decor Pieces
# 996  08ORD100271  2025-05-15          Corporate  Central             Rugs
# 997  08ORD100861  2024-09-12  Interior Designer    North         Wall Art
# 998  08ORD100436  2024-05-15          Corporate     West         Curtains
# 999  08ORD100103  2025-05-03  Interior Designer     East             Rugs
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# ...

# %% [markdown]
# ## Task 15
#
# Convert the Order_Date column to datetime format.

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
print(df['Order_Date'].dtypes)
# Out:
# datetime64[us]

# %% [markdown]
# ## Task 16
#
# Extract only the year from Order_Date into a new column named Order_Year.

# %%
df['Order_Year'] = df['Order_Date'].dt.year
print(df[['Order_ID','Order_Year']].head(8))
# Out:
#       Order_ID  Order_Year
# 0  08ORD100522        2025
# 1  08ORD100738        2025
# 2  08ORD100741        2025
# 3  08ORD100661        2024
# 4  08ORD100412        2024
# 5  08ORD100679        2024
# 6  08ORD100627        2025
# 7  08ORD100514        2025

# %% [markdown]
# ## Task 17
#
# Extract the month name from Order_Date into a new column named Order_Month.

# %%
df['Order_Month'] = df['Order_Date'].dt.month
print(df[['Order_ID','Order_Month']].head(10))
# Out:
#       Order_ID  Order_Month
# 0  08ORD100522            6
# 1  08ORD100738            1
# 2  08ORD100741            9
# 3  08ORD100661            9
# 4  08ORD100412            3
# 5  08ORD100679           11
# 6  08ORD100627           10
# 7  08ORD100514            3
# 8  08ORD100860           12
# 9  08ORD100137            3

# %% [markdown]
# ## Task 18
#
# Extract the weekday name from Order_Date into a new column named Order_Day.

# %%
df['Order_Day'] = df['Order_Date'].dt.weekday
print(df[['Order_ID','Order_Day']].head(10))
# Out:
#       Order_ID  Order_Day
# 0  08ORD100522          0
# 1  08ORD100738          2
# 2  08ORD100741          2
# 3  08ORD100661          4
# 4  08ORD100412          0
# 5  08ORD100679          1
# 6  08ORD100627          2
# 7  08ORD100514          6
# 8  08ORD100860          6
# 9  08ORD100137          3

# %% [markdown]
# ## Task 19
#
# Display a random sample of 12 rows.

# %%
df.sample(12,random_state=42)  #it displays the random 12 samples from the dataset
# Out:
#         Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 521  08ORD100667 2024-10-31  Interior Designer    North             Rugs
# 737  08ORD100130 2024-06-01        Residential  Central             Rugs
# 740  08ORD100785 2024-08-27          Corporate    North             Rugs
# 660  08ORD100153 2024-03-23         Gift Buyer    North         Lighting
# 411  08ORD100921 2025-10-31          Corporate    North             Rugs
# 678  08ORD100946 2025-01-06        Residential  Central     Decor Pieces
# 626  08ORD100049 2025-05-30          Corporate     East         Wall Art
# 513  08ORD100016 2024-08-20        Residential     East         Lighting
# 859  08ORD100773 2025-04-26        Residential    North         Wall Art
# 136  08ORD100121 2024-12-19         Gift Buyer  Central             Rugs
# 811  08ORD100171 2024-03-07         Gift Buyer     East         Lighting
# 76   08ORD100653 2025-01-16          Corporate     East         Lighting
#
# ...

# %% [markdown]
# ## Task 20
#
# Rename Discount_Percent to Discount.

# %%
df = df.rename(columns={'Discount_Percent':"Discount"})
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_Segment',
#  'Region',
#  'Product_Category',
#  'Payment_Method',
#  'Quantity',
#  'Unit_Price',
#  'Discount',
#  'Order_Value',
#  'Order_Year',
#  'Order_Month',
#  'Order_Day',
#  'Discount']

# %% [markdown]
# ## Task 21
#
# Change the column name back from Discount to Discount_Percent.

# %%
df = df.rename(columns={'Discount':'Discount_Percent'})
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_Segment',
#  'Region',
#  'Product_Category',
#  'Payment_Method',
#  'Quantity',
#  'Unit_Price',
#  'Discount_Percent',
#  'Order_Value',
#  'Order_Year',
#  'Order_Month',
#  'Order_Day',
#  'Discount_Percent']

# %% [markdown]
# ## Task 22
#
# Set Order_ID as the index.

# %%
df.set_index('Order_ID')
df.head(10)
# Out:
#       Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 0  08ORD100522 2025-06-02  Interior Designer     West     Decor Pieces
# 1  08ORD100738 2025-01-08  Interior Designer     West         Wall Art
# 2  08ORD100741 2025-09-24        Residential     West         Wall Art
# 3  08ORD100661 2024-09-06        Residential    South             Rugs
# 4  08ORD100412 2024-03-25          Corporate     West         Wall Art
# 5  08ORD100679 2024-11-19        Residential  Central         Curtains
# 6  08ORD100627 2025-10-08        Residential  Central     Decor Pieces
# 7  08ORD100514 2025-03-09         Gift Buyer  Central         Curtains
# 8  08ORD100860 2024-12-01         Gift Buyer     East         Wall Art
# 9  08ORD100137 2025-03-06          Corporate     East             Rugs
#
#      Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0  Cash on Delivery         3     2003.04                24      4566.93
# ...

# %% [markdown]
# ## Task 23
#
# Reset the index back to default integer index.

# %%
df.reset_index()
df.head(10)
# Out:
#       Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 0  08ORD100522 2025-06-02  Interior Designer     West     Decor Pieces
# 1  08ORD100738 2025-01-08  Interior Designer     West         Wall Art
# 2  08ORD100741 2025-09-24        Residential     West         Wall Art
# 3  08ORD100661 2024-09-06        Residential    South             Rugs
# 4  08ORD100412 2024-03-25          Corporate     West         Wall Art
# 5  08ORD100679 2024-11-19        Residential  Central         Curtains
# 6  08ORD100627 2025-10-08        Residential  Central     Decor Pieces
# 7  08ORD100514 2025-03-09         Gift Buyer  Central         Curtains
# 8  08ORD100860 2024-12-01         Gift Buyer     East         Wall Art
# 9  08ORD100137 2025-03-06          Corporate     East             Rugs
#
#      Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0  Cash on Delivery         3     2003.04                24      4566.93
# ...

# %% [markdown]
# ## Task 24
#
# Sort the DataFrame by Order_Value in descending order.

# %%
sortedValues = df.sort_values('Order_Value',ascending=False)
print(sortedValues.head(8))
# Out:
#         Order_ID Order_Date   Customer_Segment Region Product_Category  \
# 175  08ORD100364 2024-04-19          Corporate   East             Rugs
# 486  08ORD100043 2025-12-04  Interior Designer   West         Wall Art
# 928  08ORD100340 2025-01-07  Interior Designer  North             Rugs
# 663  08ORD100756 2024-03-26  Interior Designer  North     Decor Pieces
# 38   08ORD100902 2025-04-07  Interior Designer  North             Rugs
# 303  08ORD100423 2024-04-11  Interior Designer   West         Wall Art
# 579  08ORD100626 2024-03-26        Residential   East     Decor Pieces
# 265  08ORD100869 2025-07-08  Interior Designer   West             Rugs
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 175            UPI         4    24669.32                 1     97690.51
# 486            EMI         4    23245.34                 7     86472.66
# 928    Credit Card         4    23876.54                10     85955.54
# ...

# %% [markdown]
# ## Task 25
#
# Sort the DataFrame by Quantity ascending and Unit_Price descending.

# %%
df.sort_values(['Quantity','Unit_Price'],ascending=[True,False]).head(9)
# Out:
#         Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 909  08ORD100477 2025-06-25         Gift Buyer    North         Curtains
# 800  08ORD100557 2025-02-07  Interior Designer    North         Curtains
# 552  08ORD100694 2025-05-29  Interior Designer  Central         Curtains
# 240  08ORD100004 2025-08-18          Corporate    South         Curtains
# 42   08ORD100313 2024-02-29  Interior Designer  Central         Lighting
# 673  08ORD100673 2024-06-16         Gift Buyer     West         Lighting
# 226  08ORD100545 2024-05-15         Gift Buyer    North         Curtains
# 868  08ORD100063 2024-09-09          Corporate    South         Curtains
# 191  08ORD100830 2024-12-14         Gift Buyer     East             Rugs
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 909               UPI         1    24998.31                16     20998.58
# 800        Debit Card         1    24961.07                19     20218.47
# ...

# %% [markdown]
# ## Task 26
#
# Filter all rows where Region is North.

# %%
df.query('Region == "North"').head(20)
# Out:
#        Order_ID Order_Date   Customer_Segment Region Product_Category  \
# 10  08ORD100812 2024-12-22  Interior Designer  North         Curtains
# 14  08ORD100939 2025-01-16  Interior Designer  North         Lighting
# 19  08ORD100320 2025-09-04          Corporate  North     Decor Pieces
# 25  08ORD100236 2024-07-24  Interior Designer  North         Lighting
# 26  08ORD100102 2024-04-16          Corporate  North         Curtains
# 37  08ORD100585 2024-10-27         Gift Buyer  North         Lighting
# 38  08ORD100902 2025-04-07  Interior Designer  North             Rugs
# 44  08ORD100300 2025-12-29        Residential  North         Wall Art
# 46  08ORD100925 2025-08-20          Corporate  North         Curtains
# 52  08ORD100262 2024-05-18        Residential  North         Wall Art
# 65  08ORD100693 2024-01-09  Interior Designer  North         Lighting
# 66  08ORD100663 2025-03-26  Interior Designer  North             Rugs
# ...

# %% [markdown]
# ## Task 27
#
# Filter all rows where Payment_Method is UPI.

# %%
df.query('Payment_Method == "UPI"').head(15)
# Out:
#        Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 7   08ORD100514 2025-03-09         Gift Buyer  Central         Curtains
# 13  08ORD100974 2025-06-18        Residential     East         Lighting
# 14  08ORD100939 2025-01-16  Interior Designer    North         Lighting
# 17  08ORD100884 2025-07-17         Gift Buyer     West     Decor Pieces
# 20  08ORD100550 2024-12-24          Corporate  Central         Wall Art
# 21  08ORD100175 2025-07-08          Corporate    South         Wall Art
# 24  08ORD100211 2024-09-15         Gift Buyer     West     Decor Pieces
# 35  08ORD100199 2025-01-30        Residential     East             Rugs
# 36  08ORD100688 2025-02-08          Corporate  Central     Decor Pieces
# 38  08ORD100902 2025-04-07  Interior Designer    North             Rugs
# 43  08ORD100975 2025-11-04         Gift Buyer    South         Lighting
# 49  08ORD100838 2024-11-14  Interior Designer    South         Lighting
# ...

# %% [markdown]
# ## Task 28
#
# Filter all rows where Quantity is greater than 3.

# %%
df.query('Quantity > 3').head(13)
# Out:
#        Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 21  08ORD100175 2025-07-08          Corporate    South         Wall Art
# 23  08ORD100528 2025-09-30         Gift Buyer  Central             Rugs
# 29  08ORD100948 2025-02-15  Interior Designer  Central         Lighting
# 30  08ORD100347 2025-08-19  Interior Designer     West         Curtains
# 35  08ORD100199 2025-01-30        Residential     East             Rugs
# 38  08ORD100902 2025-04-07  Interior Designer    North             Rugs
# 46  08ORD100925 2025-08-20          Corporate    North         Curtains
# 50  08ORD100571 2025-11-20  Interior Designer     West             Rugs
# 69  08ORD100544 2025-10-02  Interior Designer     West             Rugs
# 73  08ORD100742 2024-04-26        Residential    North         Lighting
# 82  08ORD100276 2024-05-01         Gift Buyer    North         Wall Art
# 87  08ORD100715 2025-10-23          Corporate  Central         Wall Art
# ...

# %% [markdown]
# ## Task 29
#
# Filter all rows where Order_Value is above 5000.

# %%
df[df['Order_Value'] > 5000].head(20)
# Out:
#        Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 1   08ORD100738 2025-01-08  Interior Designer     West         Wall Art
# 2   08ORD100741 2025-09-24        Residential     West         Wall Art
# 3   08ORD100661 2024-09-06        Residential    South             Rugs
# 5   08ORD100679 2024-11-19        Residential  Central         Curtains
# 6   08ORD100627 2025-10-08        Residential  Central     Decor Pieces
# 7   08ORD100514 2025-03-09         Gift Buyer  Central         Curtains
# 8   08ORD100860 2024-12-01         Gift Buyer     East         Wall Art
# 9   08ORD100137 2025-03-06          Corporate     East             Rugs
# 11  08ORD100077 2025-07-18         Gift Buyer     East             Rugs
# 12  08ORD100637 2025-10-10        Residential     East             Rugs
# 14  08ORD100939 2025-01-16  Interior Designer    North         Lighting
# 15  08ORD100900 2025-01-02         Gift Buyer     East     Decor Pieces
# ...

# %% [markdown]
# ## Task 30
#
# Filter rows where Discount_Percent is between 10 and 20.

# %%
df[df['Discount_Percent'].between(10,20)].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df[df['Discount_Percent'].between(10,20)].head()
#
# File c:\Users\Dikshant.Singh\PythonTraining\myenv2\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'between'

# %% [markdown]
# ## Task 31
#
# Filter rows where Product_Category belongs to a given list of two categories.

# %% [markdown]
# ## Task 32
#
# Find all unique values in Customer_Segment.

# %%
df['Customer_Segment'].unique().tolist()
# Out:
# ['Interior Designer', 'Residential', 'Corporate', 'Gift Buyer']

# %% [markdown]
# ## Task 33
#
# Count the number of unique values in Product_Category.

# %%
df['Product_Category'].unique().tolist()
# Out:
# ['Decor Pieces', 'Wall Art', 'Rugs', 'Curtains', 'Lighting']

# %% [markdown]
# ## Task 34
#
# Display value counts for Region.

# %%
df['Region'].value_counts()
# Out:
# Region
# Central    224
# North      210
# West       204
# South      184
# East       178
# Name: count, dtype: int64

# %% [markdown]
# ## Task 35
#
# Display value counts for Payment_Method.

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# UPI                 221
# Debit Card          209
# Cash on Delivery    194
# EMI                 190
# Credit Card         186
# Name: count, dtype: int64

# %% [markdown]
# ## Task 36
#
# Find the minimum, maximum, and mean of Unit_Price.

# %%
df['Unit_Price'].dropna().min(),df['Unit_Price'].dropna().max(),df['Unit_Price'].dropna().mean()
# Out:
# (np.float64(151.33), np.float64(24998.31), np.float64(12278.09622))

# %% [markdown]
# ## Task 37
#
# Find the total sum of Order_Value.

# %%
df['Order_Value'].dropna().sum()
# Out:
# np.float64(18932113.759999998)

# %% [markdown]
# ## Task 38
#
# Find the median of Quantity.

# %%
df['Quantity'].dropna().median()
# Out:
# np.float64(2.0)

# %% [markdown]
# ## Task 39
#
# Find the standard deviation of Order_Value.

# %%
df['Order_Value'].dropna().std()
# Out:
# np.float64(16427.712463714917)

# %% [markdown]
# ## Task 40
#
# Create a new column Gross_Value as Quantity multiplied by Unit_Price.

# %%
df['Gross_Value'] = df['Quantity'] * df['Unit_Price']
print(df[['Gross_Value','Quantity','Unit_Price']].head(15))
# Out:
#     Gross_Value  Quantity  Unit_Price
# 0       6009.12         3     2003.04
# 1      18395.73         3     6131.91
# 2      21880.64         2    10940.32
# 3       9917.44         1     9917.44
# 4       4145.92         1     4145.92
# 5      34096.96         2    17048.48
# 6       5347.95         3     1782.65
# 7      26158.54         2    13079.27
# 8      10018.63         1    10018.63
# 9      28730.84         2    14365.42
# 10      5655.95         1     5655.95
# 11      8583.19         1     8583.19
# 12     22898.74         1    22898.74
# 13       603.64         1      603.64
# 14     22495.05         1    22495.05

# %% [markdown]
# ## Task 41
#
# Verify whether Gross_Value and Order_Value are consistent after discount calculation.

# %% [markdown]
# ## Task 42
#
# Create a new column Discount_Amount.

# %%
df['Discount_Amount'] = (df['Gross_Value'] - df['Order_Value']).round(2)
print(df[['Gross_Value','Order_Value','Discount_Amount']].head(10))
# Out:
#    Gross_Value  Order_Value  Discount_Amount
# 0      6009.12      4566.93          1442.19
# 1     18395.73     16188.24          2207.49
# 2     21880.64     20567.80          1312.84
# 3      9917.44      8529.00          1388.44
# 4      4145.92      3731.33           414.59
# 5     34096.96     22163.02         11933.94
# 6      5347.95      5347.95             0.00
# 7     26158.54     24065.86          2092.68
# 8     10018.63      6211.55          3807.08
# 9     28730.84     17813.12         10917.72

# %% [markdown]
# ## Task 43
#
# Create a new column High_Value_Order where Order_Value > 5000 is Yes otherwise No.

# %%
df['High_Value_Order'] = np.where(df['Order_Value'] > 5000, 'Yes', 'No')
print(df['High_Value_Order'].head(10))
# Out:
# 0     No
# 1    Yes
# 2    Yes
# 3    Yes
# 4     No
# 5    Yes
# 6    Yes
# 7    Yes
# 8    Yes
# 9    Yes
# Name: High_Value_Order, dtype: str

# %% [markdown]
# ## Task 44
#
# Use apply() to categorize Unit_Price into Low, Medium, High.

# %% [markdown]
# ## Task 45
#
# Find the top 10 highest Order_Value rows.

# %%
df.nlargest(10,'Order_Value')
# Out:
#         Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 175  08ORD100364 2024-04-19          Corporate     East             Rugs
# 486  08ORD100043 2025-12-04  Interior Designer     West         Wall Art
# 928  08ORD100340 2025-01-07  Interior Designer    North             Rugs
# 663  08ORD100756 2024-03-26  Interior Designer    North     Decor Pieces
# 38   08ORD100902 2025-04-07  Interior Designer    North             Rugs
# 303  08ORD100423 2024-04-11  Interior Designer     West         Wall Art
# 579  08ORD100626 2024-03-26        Residential     East     Decor Pieces
# 265  08ORD100869 2025-07-08  Interior Designer     West             Rugs
# 930  08ORD100565 2025-01-21         Gift Buyer  Central     Decor Pieces
# 890  08ORD100749 2024-11-15          Corporate     East         Lighting
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 175            UPI         4    24669.32                 1     97690.51
# ...

# %% [markdown]
# ## Task 46
#
# Find the bottom 10 lowest Order_Value rows.

# %%
df.nsmallest(10,'Order_Value')
# Out:
#         Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 974  08ORD100414 2024-11-06         Gift Buyer     East             Rugs
# 937  08ORD100388 2024-12-16  Interior Designer    South     Decor Pieces
# 168  08ORD100315 2024-02-28  Interior Designer    North     Decor Pieces
# 112  08ORD100986 2025-06-27  Interior Designer    South         Wall Art
# 67   08ORD100867 2024-06-12        Residential    North         Curtains
# 876  08ORD100065 2025-07-17          Corporate    North         Curtains
# 446  08ORD100634 2024-05-06          Corporate  Central         Lighting
# 200  08ORD100030 2025-03-31         Gift Buyer  Central     Decor Pieces
# 13   08ORD100974 2025-06-18        Residential     East         Lighting
# 402  08ORD100540 2025-11-14        Residential     East             Rugs
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 974    Credit Card         1      164.23                27       119.89
# ...

# %% [markdown]
# ## Task 47
#
# Group by Region and calculate average Order_Value.

# %%
df.groupby('Region')['Order_Value'].mean()
# Out:
# Region
# Central    18050.488705
# East       18898.072135
# North      19630.310190
# South      17350.976304
# West       20637.267990
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 48
#
# Group by Product_Category and calculate total sales.

# %%
df.groupby('Product_Category')['Order_Value'].sum().sort_values(ascending=True)
# Out:
# Product_Category
# Lighting        3386410.47
# Decor Pieces    3528975.55
# Curtains        3731679.30
# Wall Art        3785798.80
# Rugs            4499249.64
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 49
#
# Group by Payment_Method and calculate total Quantity sold.

# %%
df.groupby('Payment_Method')['Quantity'].sum().sort_values(ascending=True)
# Out:
# Payment_Method
# Cash on Delivery    361
# Credit Card         384
# EMI                 389
# Debit Card          417
# UPI                 450
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Task 50
#
# Group by Customer_Segment and calculate average discount percentage.

# %%
df.groupby('Customer_Segment')['Discount_Percent'].mean()
# Out:
#                    Discount_Percent  Discount_Percent
# Customer_Segment
# Corporate                 22.470339         22.470339
# Gift Buyer                22.520661         22.520661
# Interior Designer         21.515504         21.515504
# Residential               22.840909         22.840909

# %% [markdown]
# ## Task 51
#
# Perform multi-level grouping by Region and Product_Category and compute total Order_Value.

# %%
df.groupby(['Region','Product_Category'])['Order_Value'].sum().sort_values(ascending=True)
# Out:
# Region   Product_Category
# South    Decor Pieces         453106.08
# East     Curtains             471943.61
#          Wall Art             506987.96
# North    Lighting             559764.69
# Central  Lighting             618653.39
# South    Curtains             620297.47
#          Rugs                 641889.25
#          Wall Art             691788.92
# West     Lighting             694381.07
# East     Decor Pieces         707885.04
# West     Decor Pieces         708420.16
# East     Lighting             728113.40
# Central  Rugs                 768792.49
#          Decor Pieces         774145.25
# North    Curtains             779482.60
# South    Lighting             785497.92
# West     Curtains             790724.59
# North    Wall Art             811549.73
# Central  Wall Art             812487.31
# North    Decor Pieces         885419.02
# East     Rugs                 948926.83
# West     Wall Art             962984.88
#          Rugs                1053491.97
# ...

# %% [markdown]
# ## Task 52
#
# Aggregate Quantity, Unit_Price, and Order_Value with multiple statistics using agg().

# %%
df[['Quantity','Unit_Price','Order_Value']].agg(['min','max','mean','median','std','sum'])
# Out:
#            Quantity    Unit_Price   Order_Value
# min        1.000000  1.513300e+02  1.198900e+02
# max        4.000000  2.499831e+04  9.769051e+04
# mean       2.001000  1.227810e+04  1.893211e+04
# median     2.000000  1.190312e+04  1.384561e+04
# std        1.088202  7.232055e+03  1.642771e+04
# sum     2001.000000  1.227810e+07  1.893211e+07

# %% [markdown]
# ## Task 53
#
# Create a pivot table showing total Order_Value by Region and Payment_Method.

# %%
pd.pivot_table(df,values='Order_Value',index='Region',columns='Payment_Method',aggfunc=sum)
# Out:
# Payment_Method  Cash on Delivery  Credit Card  Debit Card        EMI  \
# Region
# Central                652235.60    736050.32  1019061.39  798894.40
# East                   648780.87    691975.63   676714.64  604843.43
# North                  454743.45    997035.51   958527.72  642317.36
# South                  644579.37    548632.03   612397.91  638794.46
# West                   800862.11    781671.25   885836.53  872265.41
#
# Payment_Method         UPI
# Region
# Central          837067.76
# East             741542.27
# North           1069741.10
# South            748175.87
# West             869367.37

# %% [markdown]
# ## Task 54
#
# Create a pivot table showing average Unit_Price by Product_Category and Customer_Segment.

# %%
pd.pivot_table(df,values='Unit_Price',index='Product_Category',columns='Customer_Segment',aggfunc='mean')
# Out:
# Customer_Segment     Corporate    Gift Buyer  Interior Designer   Residential
# Product_Category
# Curtains          13497.696250  13033.177805       10471.071897  11934.701724
# Decor Pieces      14027.724595  11743.487273       11116.875641  11903.632982
# Lighting          12724.674318  12544.726667       11763.694773  12393.503036
# Rugs              11599.596364  12859.936429       13308.944500  11696.728333
# Wall Art          13046.775962  12014.814667       11788.195965  12758.925333

# %% [markdown]
# ## Task 55
#
# Count the number of orders placed in each month.

# %%
df.groupby(df['Order_Date'].dt.month_name())['Order_ID'].count()
# Out:
# Order_Date
# April        67
# August       88
# December     92
# February     76
# January      87
# July         70
# June         69
# March        96
# May          95
# November     92
# October      87
# September    81
# Name: Order_ID, dtype: int64

# %% [markdown]
# ## Task 56
#
# Find the month with the highest total sales.

# %%
df.groupby(df['Order_Date'].dt.month_name())['Order_Value'].sum().sort_values(ascending=False).head(1)
# Out:
# Order_Date
# November    2034367.47
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 57
#
# Find the region with the highest average order value.

# %%
df.groupby('Region')['Order_Value'].max().sort_values(ascending=False).head(1)
# Out:
# Region
# East    97690.51
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 58
#
# Find the product category with the highest total quantity sold.

# %%
df.groupby('Product_Category')['Quantity'].sum().sort_values(ascending=False).head(1)
# Out:
# Product_Category
# Rugs    463
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Task 59
#
# Use query() to filter rows where Quantity >= 2 and Discount_Percent >= 15.

# %%
df.query('Quantity >= 2 and Discount_Percent >= 15').head(10)
# Out:
#        Order_ID Order_Date   Customer_Segment   Region Product_Category  \
# 0   08ORD100522 2025-06-02  Interior Designer     West     Decor Pieces
# 5   08ORD100679 2024-11-19        Residential  Central         Curtains
# 9   08ORD100137 2025-03-06          Corporate     East             Rugs
# 15  08ORD100900 2025-01-02         Gift Buyer     East     Decor Pieces
# 17  08ORD100884 2025-07-17         Gift Buyer     West     Decor Pieces
# 18  08ORD100762 2025-10-20  Interior Designer     West             Rugs
# 21  08ORD100175 2025-07-08          Corporate    South         Wall Art
# 23  08ORD100528 2025-09-30         Gift Buyer  Central             Rugs
# 25  08ORD100236 2024-07-24  Interior Designer    North         Lighting
# 27  08ORD100987 2025-12-25         Gift Buyer     West         Wall Art
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0   Cash on Delivery         3     2003.04                24      4566.93
# ...

# %% [markdown]
# ## Task 60
#
# Select only Order_ID, Region, Product_Category, and Order_Value columns.

# %%
df[['Order_ID','Region','Product_Category','Order_Value']].head(20)
# Out:
#        Order_ID   Region Product_Category  Order_Value
# 0   08ORD100522     West     Decor Pieces      4566.93
# 1   08ORD100738     West         Wall Art     16188.24
# 2   08ORD100741     West         Wall Art     20567.80
# 3   08ORD100661    South             Rugs      8529.00
# 4   08ORD100412     West         Wall Art      3731.33
# 5   08ORD100679  Central         Curtains     22163.02
# 6   08ORD100627  Central     Decor Pieces      5347.95
# 7   08ORD100514  Central         Curtains     24065.86
# 8   08ORD100860     East         Wall Art      6211.55
# 9   08ORD100137     East             Rugs     17813.12
# 10  08ORD100812    North         Curtains      3167.33
# 11  08ORD100077     East             Rugs      7810.70
# 12  08ORD100637     East             Rugs     15342.16
# 13  08ORD100974     East         Lighting       368.22
# 14  08ORD100939    North         Lighting     21820.20
# 15  08ORD100900     East     Decor Pieces     32653.08
# ...

# %% [markdown]
# ## Task 61
#
# Reorder the columns in any meaningful custom order.

# %%
df[['Order_ID','Order_Date','Region','Customer_Segment','Product_Category','Payment_Method','Quantity','Unit_Price','Discount_Percent','Order_Value']]
# Out:
#         Order_ID Order_Date   Region   Customer_Segment Product_Category  \
# 0    08ORD100522 2025-06-02     West  Interior Designer     Decor Pieces
# 1    08ORD100738 2025-01-08     West  Interior Designer         Wall Art
# 2    08ORD100741 2025-09-24     West        Residential         Wall Art
# 3    08ORD100661 2024-09-06    South        Residential             Rugs
# 4    08ORD100412 2024-03-25     West          Corporate         Wall Art
# ..           ...        ...      ...                ...              ...
# 995  08ORD100107 2025-08-18     West  Interior Designer     Decor Pieces
# 996  08ORD100271 2025-05-15  Central          Corporate             Rugs
# 997  08ORD100861 2024-09-12    North  Interior Designer         Wall Art
# 998  08ORD100436 2024-05-15     West          Corporate         Curtains
# 999  08ORD100103 2025-05-03     East  Interior Designer             Rugs
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  \
# ...

# %% [markdown]
# ## Task 62
#
# Find rows where Order_Value is above the overall average order value.

# %%
df['Order_Value']

# %% [markdown]
# ## Task 63
#
# Find rows where Unit_Price is below the 25th percentile.

# %% [markdown]
# ## Task 64
#
# Find the correlation between Quantity, Unit_Price, Discount_Percent, and Order_Value.

# %% [markdown]
# ## Task 65
#
# Export the top 50 highest value orders to a CSV file.

# %% [markdown]
# ## Task 66
#
# Create a bar chart of total Order_Value by Region using Matplotlib.

# %% [markdown]
# ## Task 67
#
# Create a bar chart of total Quantity sold by Product_Category using Seaborn.

# %% [markdown]
# ## Task 68
#
# Create a histogram of Unit_Price using Matplotlib.

# %% [markdown]
# ## Task 69
#
# Create a histogram of Order_Value with KDE using Seaborn.

# %% [markdown]
# ## Task 70
#
# Create a boxplot of Order_Value by Region.

# %% [markdown]
# ## Task 71
#
# Create a boxplot of Unit_Price by Payment_Method.

# %% [markdown]
# ## Task 72
#
# Create a countplot of Customer_Segment.

# %% [markdown]
# ## Task 73
#
# Create a pie chart of Payment_Method distribution.

# %% [markdown]
# ## Task 74
#
# Create a line chart of monthly total sales.

# %% [markdown]
# ## Task 75
#
# Create a heatmap of correlation among numerical columns.

# %% [markdown]
# ## Task 76
#
# Create a scatter plot of Unit_Price vs Order_Value.

# %% [markdown]
# ## Task 77
#
# Create a scatter plot of Quantity vs Order_Value colored by Region using Seaborn.

# %% [markdown]
# ## Task 78
#
# Create a violin plot of Order_Value by Product_Category.

# %% [markdown]
# ## Task 79
#
# Create a stacked bar style plot of monthly sales by Region.

# %% [markdown]
# ## Task 80
#
# Create a pairplot for Quantity, Unit_Price, Discount_Percent, and Order_Value.
